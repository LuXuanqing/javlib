# %%
import requests

# %%
r = requests.get('https://www.javbus6.pw/KTKZ-022')

# %%
r.status_code
# Out:
# 200

# %%
r.encoding
# Out:
# 'UTF-8'

# %%
r.text
# Out:
# '  <!DOCTYPE html>\r\n<html>\r\n<head>\r\n<meta charset="utf-8">\r\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\r\n<meta name="renderer" content="webkit">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<title>KTKZ-022 欅坂エンターテイメント「100年に一度のアイドルを探せ！」オーディション 西野莉子 - JavBus</title>\r\n<meta name="keywords" content="KTKZ-022,新人,DMM獨家,偶像藝人,無毛,美少女,性奴,高畫質">\r\n<meta name="description" content="【發行日期】2018-04-15，【長度】129分鐘，(KTKZ-022)欅坂エンターテイメント「100年に一度のアイドルを探せ！」オーディション 西野莉子">\r\n<link rel="alternate" href="https://www.javbus6.pw/en/KTKZ-022" hreflang="en" />\r\n<link rel="alternate" href="https://www.javbus6.pw/ja/KTKZ-022" hreflang="ja" />\r\n<link rel="alternate" href="https://www.javbus6.pw/ko/KTKZ-022" hreflang="ko" />\r\n<link rel="alternate" href="https://www.javbus6.pw/KTKZ-022" hreflang="zh" />\r\n<link rel="alternate" href="https://www.javbus6.pw/KTKZ-022" hreflang="x-default" />\r\n<link rel="canonical" href="https://www.javbus6.pw/KTKZ-022" />\r\n<
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(r.text, 'html.parser')

# %%
soup
# Out:
#  <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="webkit" name="renderer"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>KTKZ-022 欅坂エンターテイメント「100年に一度のアイドルを探せ！」オーディション 西野莉子 - JavBus</title>
# <meta content="KTKZ-022,新人,DMM獨家,偶像藝人,無毛,美少女,性奴,高畫質" name="keywords"/>
# <meta content="【發行日期】2018-04-15，【長度】129分鐘，(KTKZ-022)欅坂エンターテイメント「100年に一度のアイドルを探せ！」オーディション 西野莉子" name="description"/>
# <link href="https://www.javbus6.pw/en/KTKZ-022" hreflang="en" rel="alternate"/>
# <link href="https://www.javbus6.pw/ja/KTKZ-022" hreflang="ja" rel="alternate"/>
# <link href="https://www.javbus6.pw/ko/KTKZ-022" hreflang="ko" rel="alternate"/>
# <link href="https://www.javbus6.pw/KTKZ-022" hreflang="zh" rel="alternate"/>
# <link href="https://www.javbus6.pw/KTKZ-022" hreflang="x-default" rel="alternate"/>
# <link href="https://www.javbus6.pw/KTKZ-022" rel="canonical"/>
# ...

# %%
soup.title.string
# Out:
# 'KTKZ-022 欅坂エンターテイメント「100年に一度のアイドルを探せ！」オーディション 西野莉子 - JavBus'
